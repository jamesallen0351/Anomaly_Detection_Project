# %% [markdown]
# # Notebook for answering questions from email

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

from acquire import get_cohort_data
from prepare import split_by_program
from wrangle import wrangle_cohort_data

from sklearn import metrics
from env import user, host, password

import warnings
warnings.filterwarnings("ignore")

# %%
# getting the cohort data
df = get_cohort_data()

# %%
df.head() # check_yo_head
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip   id      name      slack  start_date    end_date  \
# 0        8.0  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 1        8.0  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 2        8.0  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 3        8.0  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 4       22.0  97.105.19.61  2.0  Badlands  #badlands  2014-06-04  2014-08-22
#
#             created_at           updated_at  deleted_at  program_id
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 2  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 3  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 4  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0

# %%
# looking at the shape of the data
df.shape
# Out:
# (847330, 15)

# %%
# checking for nulls in the data
df.isna().sum()
# Out:
# date               0
# time               0
# path               1
# user_id            0
# cohort_id          0
# ip                 0
# id            774925
# name          774925
# slack         774925
# start_date    774925
# end_date      774925
# created_at    774925
# updated_at    774925
# deleted_at    847330
# program_id    774925
# dtype: int64

# %%
# reading the info_cohorts.csv that was attached to the email
info_df = pd.read_csv("info_cohorts.csv",index_col = 0)

# %%
info_df.head() # check_yo_head
# Out:
#                  name  start_date    end_date  program_id
# cohort_id
# 1              Arches  2014-02-04  2014-04-22           1
# 2            Badlands  2014-06-04  2014-08-22           1
# 3            Carlsbad  2014-09-04  2014-11-05           1
# 4              Denali  2014-10-20  2015-01-18           1
# 5          Everglades  2014-11-18  2015-02-24           1

# %%
# taking a look at the whole .csv
info_df
# Out:
#                  name  start_date    end_date  program_id
# cohort_id
# 1              Arches  2014-02-04  2014-04-22           1
# 2            Badlands  2014-06-04  2014-08-22           1
# 3            Carlsbad  2014-09-04  2014-11-05           1
# 4              Denali  2014-10-20  2015-01-18           1
# 5          Everglades  2014-11-18  2015-02-24           1
# 6            Franklin  2015-02-03  2015-05-26           1
# 7             Glacier  2015-06-05  2015-10-06           1
# 8             Hampton  2015-09-22  2016-02-06           1
# 9              Apollo  2015-03-30  2015-07-29           4
# 10             Balboa  2015-11-03  2016-03-11           4
# 11                Ike  2016-01-20  2016-05-12           1
# 12             Joshua  2016-03-08  2016-06-30           1
# 13              Kings  2016-05-23  2016-09-15           1
# 14             Lassen  2016-07-18  2016-11-10           1
# 15            Mammoth  2016-09-26  2017-02-02           2
# 16            Niagara  2016-10-26  2017-03-09           2
# 17            Olympic  2017-02-06  2017-05-25           1
# 18          Pinnacles  2017-03-27  2017-07-20           2
# 19             Quincy  2017-06-05  2017-09-22           1
# 20            Redwood  2017-07-31  2017-12-06           2
# 21            Sequoia  2017-09-27  2018-02-15           2
# 22              Teddy  2018-01-08  2018-05-17           2
# 23            Ulysses  2018-03-05  2018-07-19           2
# 24          Voyageurs  2018-05-29  2018-10-11           2
# 25           Wrangell  2018-07-23  2018-11-29           2
# 26             Xanadu  2018-09-17  2019-02-08           2
# 27           Yosemite  2018-11-05  2019-04-03           2
# 28              Staff  2014-02-04  2014-02-04           2
# 29               Zion  2019-01-22  2019-06-04           2
# 30                Ada  2019-02-04  2019-06-16           3
# 31          Andromeda  2019-03-18  2019-07-30           2
# 32         Betelgeuse  2019-05-28  2019-10-08           2
# 33              Ceres  2019-07-15  2019-12-11           2
# 34              Bayes  2019-08-19  2020-01-30           3
# 51             Deimos  2019-09-16  2020-02-27           2
# 52             Europa  2019-11-04  2020-04-17           2
# 53            Fortuna  2020-01-13  2020-06-23           2
# 55              Curie  2020-02-03  2020-07-07           3
# 56               Apex  2020-02-24  2020-07-29           2
# 57           Ganymede  2020-03-23  2020-08-20           2
# 58           Hyperion  2020-05-26  2020-11-10           2
# 59             Darden  2020-07-13  2021-01-12           3
# 60                 Io  2020-07-20  2021-01-21           2
# 61               Bash  2020-07-20  2021-01-21           2
# 62            Jupiter  2020-09-21  2021-03-30           2
# 132           Kalypso  2020-11-02  2021-05-04           2

# %%
# changing cohort_id to an integer
df = df.astype({"cohort_id": int})

# %%
df.head() # check_yo_head
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip   id      name      slack  start_date    end_date  \
# 0          8  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 1          8  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 2          8  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 3          8  97.105.19.61  1.0    Arches    #arches  2014-02-04  2014-04-22
# 4         22  97.105.19.61  2.0  Badlands  #badlands  2014-06-04  2014-08-22
#
#             created_at           updated_at  deleted_at  program_id
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 2  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 3  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 4  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0

# %%
# joining the two datframes I have
join_df = df.join(info_df,on = 'cohort_id',how = 'outer',lsuffix = 'str')

# %%
join_df.head() # check_yo_head
# Out:
#             date      time                                 path  user_id  \
# 0.0   2018-01-26  09:55:03                                    /      1.0
# 1.0   2018-01-26  09:56:02                              java-ii      1.0
# 2.0   2018-01-26  09:56:05  java-ii/object-oriented-programming      1.0
# 3.0   2018-01-26  09:56:06   slides/object_oriented_programming      1.0
# 58.0  2018-01-26  10:40:15               javascript-i/functions      1.0
#
#       cohort_id            ip   id namestr    slack start_datestr end_datestr  \
# 0.0           8  97.105.19.61  1.0  Arches  #arches    2014-02-04  2014-04-22
# 1.0           8  97.105.19.61  1.0  Arches  #arches    2014-02-04  2014-04-22
# 2.0           8  97.105.19.61  1.0  Arches  #arches    2014-02-04  2014-04-22
# 3.0           8  97.105.19.61  1.0  Arches  #arches    2014-02-04  2014-04-22
# 58.0          8  97.105.19.61  1.0  Arches  #arches    2014-02-04  2014-04-22
#
#                created_at           updated_at  deleted_at  program_idstr  \
# 0.0   2016-06-14 19:52:26  2016-06-14 19:52:26         NaN            1.0
# 1.0   2016-06-14 19:52:26  2016-06-14 19:52:26         NaN            1.0
# 2.0   2016-06-14 19:52:26  2016-06-14 19:52:26         NaN            1.0
# 3.0   2016-06-14 19:52:26  2016-06-14 19:52:26         NaN            1.0
# 58.0  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN            1.0
#
#          name  start_date    end_date  program_id
# 0.0   Hampton  2015-09-22  2016-02-06         1.0
# 1.0   Hampton  2015-09-22  2016-02-06         1.0
# 2.0   Hampton  2015-09-22  2016-02-06         1.0
# 3.0   Hampton  2015-09-22  2016-02-06         1.0
# 58.0  Hampton  2015-09-22  2016-02-06         1.0

# %%
# looking at null values in the data
join_df.isna().sum()
# Out:
# date                  5
# time                  5
# path                  6
# user_id               5
# cohort_id             0
# ip                    5
# id               774930
# namestr          774930
# slack            774930
# start_datestr    774930
# end_datestr      774930
# created_at       774930
# updated_at       774930
# deleted_at       847335
# program_idstr    774930
# name              65245
# start_date        65245
# end_date          65245
# program_id        65245
# dtype: int64

# %%
# using my wranlge_cohort_data function to do some clean up
df = wrangle_cohort_data()

# %%
df.head() # check_yo_head
# Out:
#                                                     path  user_id  cohort_id  \
# datetime
# 2018-01-26 09:56:02                              java-ii        1          8
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1          8
# 2018-01-26 09:56:06   slides/object_oriented_programming        1          8
# 2018-01-26 10:40:15               javascript-i/functions        1          8
# 2018-01-26 11:26:13                               java-i        1          8
#
#                                ip cohort_name  start_date    end_date  \
# datetime
# 2018-01-26 09:56:02  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 09:56:05  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 09:56:06  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 10:40:15  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 11:26:13  97.105.19.61     Hampton  2015-09-22  2016-02-06
#
#                      program_id  count_helper                    program_name  \
# datetime
# 2018-01-26 09:56:02         1.0             1  PHP Full Stack Web Development
# 2018-01-26 09:56:05         1.0             1  PHP Full Stack Web Development
# 2018-01-26 09:56:06         1.0             1  PHP Full Stack Web Development
# 2018-01-26 10:40:15         1.0             1  PHP Full Stack Web Development
# 2018-01-26 11:26:13         1.0             1  PHP Full Stack Web Development
#
#                     program_subdomain     slack  \
# datetime
# 2018-01-26 09:56:02               php  #hampton
# 2018-01-26 09:56:05               php  #hampton
# 2018-01-26 09:56:06               php  #hampton
# 2018-01-26 10:40:15               php  #hampton
# 2018-01-26 11:26:13               php  #hampton
#
#                                            module/lesson
# datetime
# 2018-01-26 09:56:02                                  NaN
# 2018-01-26 09:56:05  java-ii/object-oriented-programming
# 2018-01-26 09:56:06   slides/object_oriented_programming
# 2018-01-26 10:40:15               javascript-i/functions
# 2018-01-26 11:26:13                                  NaN

# %%
# taking a look at the shape of the data
df.shape
# Out:
# (739722, 13)

# %%
# using .info() to look at Dtype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 739722 entries, 2018-01-26 09:56:02 to 2021-04-21 16:32:36
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   path               739722 non-null  object
#  1   user_id            739722 non-null  int64
#  2   cohort_id          739722 non-null  int64
#  3   ip                 739722 non-null  object
#  4   cohort_name        739722 non-null  object
#  5   start_date         739722 non-null  object
#  6   end_date           739722 non-null  object
#  7   program_id         739722 non-null  float64
#  8   count_helper       739722 non-null  int64
#  9   program_name       739722 non-null  object
#  10  program_subdomain  739722 non-null  object
#  11  slack              739722 non-null  object
#  12  module/lesson      602162 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 79.0+ MB

# %%
# trying a groupby 'path'
df.groupby('path').sum().head()
# Out:
#                                   user_id  cohort_id  program_id  count_helper
# path
# %20https://github.com/RaulCPena       580         55         3.0             1
# '                                      64         28         2.0             1
# ,%20https://github.com/RaulCPena      580         55         3.0             1
# .git                                  203         24         2.0             1
# .gitignore                            899         83         5.0             2

# %%
# trying a groupby 'program_name'
df.groupby('program_name').count_helper.sum()
# Out:
# program_name
# Data Science                        73475
# Front End Web Development               4
# Java Full Stack Web Development    637376
# PHP Full Stack Web Development      28867
# Name: count_helper, dtype: int64

# %% [markdown]
# 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
# looking at all the programs
df.program_name.unique()
# Out:
# array(['PHP Full Stack Web Development',
#        'Java Full Stack Web Development', 'Front End Web Development',
#        'Data Science'], dtype=object)

# %%
# using prepare function to split into programs
php_df,java_df,ds_df,fe_df = split_by_program(df)

# %%
#php_df
php_df.groupby('cohort_name')['path','user_id'].nunique()
# Out:
#              path  user_id
# cohort_name
# Arches        341       18
# Badlands       43        3
# Denali          3        1
# Franklin       44        2
# Glacier       142        6
# Hampton       277        5
# Ike            94        5
# Joshua        116        5
# Kings         347        9
# Lassen        485       12
# Olympic       382       13
# Quincy        281       16

# %%
# idxmax to get the most viewed module/lesson
php_df.groupby(['module/lesson','cohort_name']).path.count().idxmax()
# Out:
# ('spring/fundamentals', 'Lassen')

# %%
# java_df
java_df.groupby('cohort_name')['path','user_id'].nunique()
# Out:
#              path  user_id
# cohort_name
# Andromeda     365       28
# Apex          272       24
# Bash          274       23
# Betelgeuse    333       21
# Ceres         300       29
# Deimos        287       27
# Europa        266       28
# Fortuna       257       29
# Ganymede      295       28
# Hyperion      269       23
# Jupiter       287       33
# Kalypso       272       23
# Mammoth       231        5
# Niagara       134        8
# Pinnacles     324       14
# Sequoia       311       28
# Staff        1403       49
# Teddy         543       35
# Ulysses       405       33
# Voyageurs     376       34
# Wrangell      420       26
# Xanadu        282       20
# Yosemite      313       29
# Zion          316       25

# %%
# idxmax to get the most viewed module/lesson
java_df.groupby(['module/lesson','cohort_name']).path.count().idxmax()
# Out:
# ('spring/fundamentals', 'Staff')

# %%
# ds_df
ds_df.groupby('cohort_name')['path','user_id'].nunique()
# Out:
#              path  user_id
# cohort_name
# Bayes         532       23
# Curie         417       21
# Darden        419       29

# %%
# idxmax to get the most viewed module/lesson
ds_df.groupby(['module/lesson','cohort_name']).path.count().idxmax()
# Out:
# ('classification/overview', 'Darden')

# %%
# fe_df
fe_df.groupby('cohort_name')['path','user_id'].nunique()
# Out:
#              path  user_id
# cohort_name
# Apollo          3        1

# %%
# idxmax to get the most viewed module/lesson
fe_df.groupby(['module/lesson','cohort_name']).path.count().idxmax()
# Out:
# ('content/html-css', 'Apollo')

# %% [markdown]
# 2. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?

# %%
# making a list for data science cohorts
ds_cohort_list = list(set(ds_df.cohort_name.to_list()))

# %%
# running through the data science cohorts
for cohort in ds_cohort_list:
    temp_df = df[df.cohort_name == cohort]
    print(cohort)
    print('------------------------------------------------------------')
    print(temp_df.groupby(['module/lesson']).count_helper.agg(['count']).sort_values(by = 'count',ascending = False).head(10))
    print('------------------------------------------------------------')
# Out:
# Darden
# ------------------------------------------------------------
#                                                 count
# module/lesson
# classification/overview                          1109
# classification/scale_features_or_not.svg          943
# sql/mysql-overview                                774
# search/search_index.json                          664
# anomaly-detection/AnomalyDetectionCartoon.jpeg    612
# anomaly-detection/overview                        592
# 1-fundamentals/AI-ML-DL-timeline.jpg              470
# 1-fundamentals/modern-data-scientist.jpg          470
# 1-fundamentals/1.1-intro-to-data-science          460
# stats/compare-means                               423
# ------------------------------------------------------------
# Bayes
# ------------------------------------------------------------
#                                                    count
# module/lesson
# 1-fundamentals/modern-data-scientist.jpg             650
# 1-fundamentals/AI-ML-DL-timeline.jpg                 648
# 1-fundamentals/1.1-intro-to-data-science             640
# search/search_index.json                             588
# 6-regression/1-overview                              521
# appendix/cli                                         521
# 10-anomaly-detection/AnomalyDetectionCartoon.jpeg    387
# 10-anomaly-detection/1-overview                      384
# 6-regression/5.0-evaluate                            333
# 5-stats/3-probability-distributions                  320
# ------------------------------------------------------------
# Curie
# ------------------------------------------------------------
#                                                    count
# module/lesson
# 6-regression/1-overview                              595
# search/search_index.json                             538
# 1-fundamentals/modern-data-scientist.jpg             467
# 1-fundamentals/AI-ML-DL-timeline.jpg                 465
# 1-fundamentals/1.1-intro-to-data-science             461
# 3-sql/1-mysql-overview                               441
# appendix/cli                                         409
# 10-anomaly-detection/AnomalyDetectionCartoon.jpeg    345
# 10-anomaly-detection/1-overview                      345
# 4-python/8.4.3-dataframes                            260
# ------------------------------------------------------------

# %% [markdown]
# 3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# datetime
# 2018-01-26 09:56:02                              java-ii        1          8
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1          8
# 2018-01-26 09:56:06   slides/object_oriented_programming        1          8
# 2018-01-26 10:40:15               javascript-i/functions        1          8
# 2018-01-26 11:26:13                               java-i        1          8
#
#                                ip cohort_name  start_date    end_date  \
# datetime
# 2018-01-26 09:56:02  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 09:56:05  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 09:56:06  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 10:40:15  97.105.19.61     Hampton  2015-09-22  2016-02-06
# 2018-01-26 11:26:13  97.105.19.61     Hampton  2015-09-22  2016-02-06
#
#                      program_id  count_helper                    program_name  \
# datetime
# 2018-01-26 09:56:02         1.0             1  PHP Full Stack Web Development
# 2018-01-26 09:56:05         1.0             1  PHP Full Stack Web Development
# 2018-01-26 09:56:06         1.0             1  PHP Full Stack Web Development
# 2018-01-26 10:40:15         1.0             1  PHP Full Stack Web Development
# 2018-01-26 11:26:13         1.0             1  PHP Full Stack Web Development
#
#                     program_subdomain     slack  \
# datetime
# 2018-01-26 09:56:02               php  #hampton
# 2018-01-26 09:56:05               php  #hampton
# 2018-01-26 09:56:06               php  #hampton
# 2018-01-26 10:40:15               php  #hampton
# 2018-01-26 11:26:13               php  #hampton
#
#                                            module/lesson
# datetime
# 2018-01-26 09:56:02                                  NaN
# 2018-01-26 09:56:05  java-ii/object-oriented-programming
# 2018-01-26 09:56:06   slides/object_oriented_programming
# 2018-01-26 10:40:15               javascript-i/functions
# 2018-01-26 11:26:13                                  NaN

# %% [markdown]
# 4. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP
# addresses?

# %% [markdown]
# 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?

# %%
# let's make a temp_df of 2019 to look at
temp_df = df.loc['2019']
temp_df.head()
# Out:
#                                          path  user_id  cohort_id  \
# datetime
# 2019-01-02 09:39:38  search/search_index.json       99         22
# 2019-01-02 09:39:53    javascript-ii/ajax-api       99         22
# 2019-01-02 09:40:15                  java-iii       99         22
# 2019-01-02 09:40:18         java-iii/servlets       99         22
# 2019-01-02 09:40:40             java-iii/jdbc       99         22
#
#                                 ip cohort_name  start_date    end_date  \
# datetime
# 2019-01-02 09:39:38  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:39:53  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:40:15  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:40:18  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:40:40  199.59.33.126       Teddy  2018-01-08  2018-05-17
#
#                      program_id  count_helper  \
# datetime
# 2019-01-02 09:39:38         2.0             1
# 2019-01-02 09:39:53         2.0             1
# 2019-01-02 09:40:15         2.0             1
# 2019-01-02 09:40:18         2.0             1
# 2019-01-02 09:40:40         2.0             1
#
#                                         program_name program_subdomain  \
# datetime
# 2019-01-02 09:39:38  Java Full Stack Web Development              java
# 2019-01-02 09:39:53  Java Full Stack Web Development              java
# 2019-01-02 09:40:15  Java Full Stack Web Development              java
# 2019-01-02 09:40:18  Java Full Stack Web Development              java
# 2019-01-02 09:40:40  Java Full Stack Web Development              java
#
#                       slack             module/lesson
# datetime
# 2019-01-02 09:39:38  #teddy  search/search_index.json
# 2019-01-02 09:39:53  #teddy    javascript-ii/ajax-api
# 2019-01-02 09:40:15  #teddy                       NaN
# 2019-01-02 09:40:18  #teddy         java-iii/servlets
# 2019-01-02 09:40:40  #teddy             java-iii/jdbc

# %%
# now let's get the web dev and ds programs java == 2; ds == 3
temp_df = temp_df[(temp_df.program_id == 2) | (temp_df.program_id == 3)]

# %%
temp_df.head() # check_yo_head
# Out:
#                                          path  user_id  cohort_id  \
# datetime
# 2019-01-02 09:39:38  search/search_index.json       99         22
# 2019-01-02 09:39:53    javascript-ii/ajax-api       99         22
# 2019-01-02 09:40:15                  java-iii       99         22
# 2019-01-02 09:40:18         java-iii/servlets       99         22
# 2019-01-02 09:40:40             java-iii/jdbc       99         22
#
#                                 ip cohort_name  start_date    end_date  \
# datetime
# 2019-01-02 09:39:38  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:39:53  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:40:15  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:40:18  199.59.33.126       Teddy  2018-01-08  2018-05-17
# 2019-01-02 09:40:40  199.59.33.126       Teddy  2018-01-08  2018-05-17
#
#                      program_id  count_helper  \
# datetime
# 2019-01-02 09:39:38         2.0             1
# 2019-01-02 09:39:53         2.0             1
# 2019-01-02 09:40:15         2.0             1
# 2019-01-02 09:40:18         2.0             1
# 2019-01-02 09:40:40         2.0             1
#
#                                         program_name program_subdomain  \
# datetime
# 2019-01-02 09:39:38  Java Full Stack Web Development              java
# 2019-01-02 09:39:53  Java Full Stack Web Development              java
# 2019-01-02 09:40:15  Java Full Stack Web Development              java
# 2019-01-02 09:40:18  Java Full Stack Web Development              java
# 2019-01-02 09:40:40  Java Full Stack Web Development              java
#
#                       slack             module/lesson
# datetime
# 2019-01-02 09:39:38  #teddy  search/search_index.json
# 2019-01-02 09:39:53  #teddy    javascript-ii/ajax-api
# 2019-01-02 09:40:15  #teddy                       NaN
# 2019-01-02 09:40:18  #teddy         java-iii/servlets
# 2019-01-02 09:40:40  #teddy             java-iii/jdbc
